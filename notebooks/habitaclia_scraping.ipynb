# %% [markdown]
# ## 1. Imports

# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
from tqdm import tqdm
import pandas as pd
import traceback
import sys

# %% [markdown]
# ## 2. Get Full HTML Content

# %%
url = 'https://www.habitaclia.com/viviendas-madrid.htm'
html = requests.get(url).content
soup = BeautifulSoup(html, 'html.parser')

# %% [markdown]
# ## 3. Get Specific Table & Specific Relevant Tags | Table Elements

# %%
soup_table = soup.find_all('section', {'class': 'list-items'})

unique_listings_by_page = soup_table[0].find_all('h3', {'class': 'list-item-title'})

unique_listings_by_page[0]
# Out:
# <h3 class="list-item-title">
# <a href="https://www.habitaclia.com/comprar-piso-fenomenal_arapiles-madrid-i15511003002180.htm?f=&amp;geo=p&amp;from=list&amp;lo=55" itemprop="name" target="_self" title="Piso  en  Arapiles. Fenomenal">Piso  en  Arapiles. Fenomenal</a>
# </h3>

# %% [markdown]
# ## 4. Extract unique URL's from Habitaclia to be scraped for specific data

# %% [markdown]
#  - The first page is unique. (Does NOT have a number on it, so the iteration CAN'T start with it)
#  - We can start creating the unique url's list with the first page info and append the rest later.

# %%
unique_listings_urls = []

for i in range(len(unique_listings_by_page)):
    #print(unique_listings_by_page[i].a['href'])
    if i not in unique_listings_urls:
        unique_listings_urls.append(unique_listings_by_page[i].a['href'])
    else:
        pass

print()
print('This output contains', len(unique_listings_by_page), "url's")
# Out:
# This output contains 15 url's

# %% [markdown]
# - The following part of the code is to be able to iterate from the second page till the end.

# %%
#Loop to go over all pages
pages = np.arange(1, 5000, 1)

for page in tqdm(pages[:950]):
    try:
        page="https://www.habitaclia.com/viviendas-madrid-" + str(page) + ".htm"
        html = requests.get(page).content
        soup = BeautifulSoup(html, 'html.parser')
        soup_table = soup.find_all('section', {'class': 'list-items'})
        unique_listings_by_page = soup_table[0].find_all('h3', {'class': 'list-item-title'})
        for i in range(len(unique_listings_by_page)):
            if i not in unique_listings_urls:
                unique_listings_urls.append(unique_listings_by_page[i].a['href'])
            else:
                pass
      
    except Exception as e:
        print("Oops!", e, "occurred.")
        print()
        break
# Out:
#  98%|█████████▊| 932/950 [13:46<00:15,  1.13it/s]
# Oops! list index out of range occurred.

# %%
len(unique_listings_urls)
# Out:
# 15495

# %%
unique_listings_urls[0:50]
# Out:
# ['https://www.habitaclia.com/comprar-piso-fenomenal_arapiles-madrid-i15511003002180.htm?f=&geo=p&from=list&lo=55',
#  'https://www.habitaclia.com/comprar-piso-c_doctor_juan_jose_lopez_0_valdezarza-madrid-i23878000004181.htm?f=&geo=p&from=list&lo=55',
#  'https://www.habitaclia.com/comprar-piso-con_terraza_gaztambide-madrid-i15511003002590.htm?f=&geo=p&from=list&lo=55',
#  'https://www.habitaclia.com/comprar-piso-estupendo_gaztambide-madrid-i15511003002757.htm?f=&geo=p&from=list&lo=55',
#  'https://www.habitaclia.com/comprar-triplex-acogedor_pinar_del_rey-madrid-i15511003002896.htm?f=&geo=p&from=list&lo=55',
#  'https://www.habitaclia.com/comprar-piso-genial_palos_de_moguer-madrid-i15511003002586.htm?f=&geo=p&from=list&lo=55',
#  'https://www.habitaclia.com/comprar-piso-estupendo_las_tablas-madrid-i15511003002656.htm?f=&geo=p&from=list&lo=55',
#  'https://www.habitaclia.com/comprar-piso-esplendido_universidad_malasana-madrid-i15511003002573.htm?f=&geo=p&from=list&lo=55',
#  'https://www.habitaclia.com/comprar-piso-impecable_en_lavapies_reforma_integral_embajadores_lavapies-madrid-i16424000000673.htm?f=&geo=p&from=list&lo=55',
#  'https://www.habitaclia.com/comprar-piso-obra_nueva_sol-madrid-i548003171458.htm?f=&geo=p&from=list&lo=55',
#  'https://www.habitaclia.com/comprar-atico-con_95_m2_de_terraza_en_venta_en_sol_universidad_malasana-madrid-i4975004012146.htm?f=&geo=p&from=list&lo=55',
#  'https://www.habitaclia.com/comprar-piso-acogedor_canillas-madrid-i15511003002845.htm?f=&geo=p&from=list&lo=55',
#  'https://www.habitaclia.com/comprar-piso-admirable_lista-madrid-i15511003002839.htm?f=&geo=p&from=list&lo=55',
#  'https://www.habitaclia.com/comprar-piso-maravilloso_los_carmenes-madrid-i15511003003094.htm?f=&geo=p&from=list&lo=55',
#  'https://www.habitaclia.com/comprar-piso-esplendido_san_diego-madrid-i15511003002742.htm?f=&geo=p&from=list&lo=55',
#  'https://www.habitaclia.com/comprar
        zooming_at_price[0].text
        price = zooming_at_price[0].text[:-2]
        price_list.append(price)
    
    
    except Exception as e:
        print("Oops!", print(e), "occurred.")
        print("This happenned on link:", link)
        traceback.print_exc()
        print()
        traceback.print_exception(*sys.exc_info())
        print()
        pass
# Out:
#   0%|          | 15/15495 [00:10<3:07:42,  1.37it/s]Traceback (most recent call last):
#   File "<ipython-input-201-665cfb0e165a>", line 11, in <module>
#     tag_div_class_price = summary_box_table[0].find_all('div', {'class': 'price'})
# IndexError: list index out of range
# Traceback (most recent call last):
#   File "<ipython-input-201-665cfb0e165a>", line 11, in <module>
#     tag_div_class_price = summary_box_table[0].find_all('div', {'class': 'price'})
# IndexError: list index out of range
#   0%|          | 16/15495 [00:11<2:58:36,  1.44it/s]
# list index out of range
# Oops! None occurred.
# This happenned on link: https://www.habitaclia.com/comprar-atico-admirable_legazpi-madrid-i15511003002450.htm?pag=1&f=&geo=p&from=list&lo=55
#   0%|          | 48/15495 [00:29<2:22:40,  1.80it/s]Traceback (most recent call last):
#   File "<ipython-input-201-665cfb0e165a>", line 11, in <module>
#     tag_div_class_price = summary_box_table[0].find_all('div', {'class': 'price'})
# IndexError: list index out of range
# Traceback (most recent call last):
#   File "<ipython-input-201-665cfb0e165a>", line 11, in <module>
#     tag_div_class_price = summary_box_table[0].find_all('div', {'class': 'price'})
# IndexError: list index out of range
#   0%|          | 49/15495 [00:30<2:30:00,  1.72it/s]
# list index out of range
# Oops! None occurred.
# This happenned on link: https://www.habitaclia.com/comprar-casa-chalet_pareado_en_venta_con_piscina_en_arturo_soria_piovera_conde_de_orgaz-madrid-i15240003784617.htm?pag=3&f=&geo=p&from=list&lo=55
#   1%|          | 125/15495 [01:15<2:30:10,  1.71it/s]Traceback (most recent call last):
#   File "<ipython-input-201-665cfb0e165a>", line 11, in <module>
#     tag_div_class_price = summary_box_table[0].find_all('div', {'class': 'price'})
# IndexError: list index out of range
# Traceback (most recent call last):
#   File "<ipython-input-201-665cfb0e165a>", line 11, in <module>
#     tag_div_class_price = summary_box_table[0].find_all('div', {'class': 'price'})
# IndexError: list index out of range
#   1%|          | 126/15495 [01:15<2:38:40,  1.61it/s]
# list index out of range
# Oops! None occurred.
# This happenned on link: https://www.habitaclia.com/comprar-piso-trafalgar-madrid-i20012000000108.htm?pag=8&f=&geo=p&from=list&lo=55
#   1%|          | 150/15495 [01:29<2:39:57,  1.60it/s]Traceback (most recent call last):
#   File "<ipython-input-201-665cfb0e165a>", line 11, in <module>
#     tag_div_class_price = summary_box_table[0].find_all('div', {'class': 'price'})
# IndexError: list index out of range
# Traceback (most recent call last):
#   File "<ipython-input-201-665cfb0e165a>", line 11, in <module>
#     tag_div_class_price = summary_box_table[0].find_all('div', {'class': 'price'})
# IndexError: list index out of range
#   1%|          | 151/15495 [01:30<2:35:58,  1.64it/s]
# list index out of range
# Oops! None occurred.
# This happenned on link: https://www.habitaclia.com/comprar-piso-con_2_habitaciones_con_ascensor_aluche-madrid-i33851000000008.htm?pag=10&f=&geo=p&from=list&lo=55
#   1%|          | 167/15495 [01:40<2:33:52,  1.66it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-201-665cfb0e165a> in <module>
#       7         html = requests.get(link).content
#       8         #print(link)
# ----> 9         unique_soup = BeautifulSoup(html, 'html.parser')
#      10         summary_box_table = unique_soup.find_all('div', {'class': 'summary-left'})
#      11         tag_div_class_price = summary_box_table[0].find_all('div', {'class': 'price'})
#
# ~/miniconda3/envs/ironhack_env/lib/python3.8/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     346             self.reset()
#     347             try:
# --> 348                 self._feed()
#     349                 success = True
#     350                 break
#
# ~/miniconda3/envs/ironhack_env/lib/python3.8/site-packages/bs4/__init__.py in _feed(self)
#     432         self.builder.reset()
#     433
# --> 434         self.builder.feed(self.markup)
#     435         # Close out any unfinished strings and close all the open tags.
#     436         self.endData()
#
# ~/miniconda3/envs/ironhack_env/lib/python3.8/site-packages/bs4/builder/_htmlparser.py in feed(self, markup)
#     375         parser.soup = self.soup
#     376         try:
# --> 377             parser.feed(markup)
#     378             parser.close()
#     379         except HTMLParseError as e:
#
# ~/miniconda3/envs/ironhack_env/lib/python3.8/html/parser.py in feed(self, data)
#     109         """
#     110         self.rawdata = self.rawdata + data
# --> 111         self.goahead(0)
#     112
#     113     def close(self):
#
# ~/miniconda3/envs/ironhack_env/lib/python3.8/html/parser.py in goahead(self, end)
#     169             if startswith('<', i):
#     170                 if starttagopen.match(rawdata, i): # < + letter
# --> 171                     k = self.parse_starttag(i)
#     172                 elif startswith("</", i):
#     173                     k = self.parse_endtag(i)
#
# ~/miniconda3/envs/ironhack_env/lib/python3.8/html/parser.py in parse_starttag(self, i)
#     308
#     309         # Now parse the data between i+1 and j into a tag and attrs
# --> 310         attrs = []
#     311         match = tagfind_tolerant.match(rawdata, i+1)
#     312         assert match, 'unexpected call to parse_starttag()'
#
# KeyboardInterrupt:

# %%
print(price_list[0:10])
# Out:
# ['479.000', '710.000', '640.000', '380.000', '299.900', '190.000', '360.000', '349.900', '290.000', '470.000']

# %%
# To generate location list

location_list = []

for link in tqdm(unique_listings_urls):
    html = requests.get(link).content
    unique_soup = BeautifulSoup(html, 'html.parser')
    summary_box_table = unique_soup.find_all('div', {'class': 'summary-left'})
    zooming_location = summary_box_table[0].find_all('article', {'class': 'location'})
    pinned_location = zooming_location[0].find_all('a', {'class': 'jqVerMapaZonaTooltip link-map-location'})
    location = pinned_location[0].get('title')
    location_name = location[4:]
    location_list.append(location_name)
# Out:
# 100%|██████████| 1515/1515 [16:37<00:00,  1.52it/s]

# %%
print(location_list[0:10])
# Out:
# ['Arapiles', 'Valdezarza', 'Gaztambide', 'Gaztambide', 'Pinar del Rey', 'Palos de Moguer', 'Las Tablas', 'Universidad-Malasaña', 'Embajadores-Lavapiés', 'Sol']

# %%
# To generate squared meters, # rooms, # of bathrooms and price per squared meter lists.
# We take this informatioin from the feature container in the summary.

squared_meters_list = []
number_of_rooms_list = []
number_of_bathrooms_list = []
euros_per_meter_list = []

for link in tqdm(unique_listings_urls):
    html = requests.get(link).content
    unique_soup = BeautifulSoup(html, 'html.parser')
    summary_box_table = unique_soup.find_all('div', {'class': 'summary-left'})
    feature_container = summary_box_table[0].find_all('ul', {'class': 'feature-container'})
    
    #THIS PART TO EXTRACT THE SQUARED METERS.
    if str('m2') in feature_container[0].text.strip():
        squared_meters_list.append(feature_container[0].text[:feature_container[0].text.find('m2')].strip())
    else:
        squared_meters_list.append(np.NaN)
        
    #THIS PART TO FIND AND EXTRACT THE NUMBER OF ROOMS.
    if str('hab') in feature_container[0].text:
        number_of_rooms_list.append(feature_container[0].text[int(feature_container[0].text.find('hab'))-4:int(feature_container[0].text.find('hab'))].strip())
    else:
        number_of_rooms_list.append(np.NaN)

    #THIS PART TO FIND AND EXTRACT THE NUMBER OF BATHROOMS.
    if str('baño') in feature_container[0].text:
        number_of_bathrooms_list.append(feature_container[0].text[int(feature_container[0].text.find('baño'))-3:int(feature_container[0].text.find('baño'))].strip())
    else:
        number_of_bathrooms_list.append(np.NaN)
    
    #THIS PART TO FIND AND EXTRACT THE PRICE PER SQUARE METER. THIS WILL ALSO HELP TO VERIFY IF THE SCRAPING WAS SUCCESSFUL.
    if str('€/m') in feature_container[0].text:
        euros_per_meter_list.append(feature_container[0].text[int(feature_container[0].text.find('€/m'))-8:int(feature_container[0].text.find('€/m'))].strip())
    else:
        euros_per_meter_list.append(np.NaN)
# Out:
# 100%|██████████| 1515/1515 [16:58<00:00,  1.49it/s]

# %%
print(squared_meters_list[0:10])
print(number_of_rooms_list[0:10])
print(number_of_bathrooms_list[0:10])
print(euros_per_meter_list[0:10])
# Out:
# ['117', '113', '188', '71', '134', '49', '93', '105', '70', 'desde \n84']
# ['3', '4', '6', '2', '3', '1', '2', '3', '2', '1']
# ['2', '3', '2', '2', '2', '1', '2', '1', '1', '1']
# ['4.094', '6.283', '3.404', '5.352', '2.238', '3.878', '3.871', '3.332', '4.143', '5.595']

# %%
print(len(squared_meters_list))
print(len(number_of_rooms_list))
print(len(number_of_bathrooms_list))
print(len(euros_per_meter_list))
# Out:
# 1515
# 1515
# 1515
# 1515

# %%
#This is to retrieve all the listing features.
#This for loop will get all the "caracteristicas principales"
#Energy certificate was a little bit tricky.

all_features_list = []
consumo_ranking_list = []
emissions_ranking_list = []
consupmtion_kilowatts_list = []
emissions_kilograms_list = []

for link in tqdm(unique_listings_urls):
    html = requests.get(link).content
    #print(link)
    unique_soup = BeautifulSoup(html, 'html.parser')
    all_listing_details = unique_soup.find_all('article', {'class': 'has-aside'})
    all_features_details = all_listing_details[2].find_all('li')
    
    
    if all_listing_details[2].find('li', {'class': 'energy-container'}) == None:
        
        #print('NO MENCIONA CERTIFICADO')
        rank_consumo = np.NaN
        rank_emisiones = np.NaN
        consupmtion_kilowatts = np.NaN
        emissions_kilograms = np.NaN

        consumo_ranking_list.append(rank_consumo)
        emissions_ranking_list.append(rank_emisiones)
        consupmtion_kilowatts_list.append(consupmtion_kilowatts)
        emissions_kilograms_list.append(emissions_kilograms)

        #print('rank_consumo:', rank_consumo)
        #print('rank_emisiones:', rank_emisiones)
        #print('consupmtion_kilowatts:', consupmtion_kilowatts)
        #print('emissions_kilograms:', emissions_kilograms)
    
    
    all_features = []

    for items in range(len(all_features_details)):
           
        if len(all_features_details[items]) == 1 and str('Certificado energético') not in all_features_details[items]: # This part of the code gets all the unique listed features.
            #print(all_features_details[items].text.strip())
            all_features.append(all_features_details[items].text.strip())

        elif len(all_features_details[items]) == 5: # This part of the code gets the energy related metrics if available.
            energy_certificate = all_features_details[-1].find_all('div', {'class': 'rating-box'})
            consumo = energy_certificate[0].text.replace('\r\n', '').strip().split()
            emisiones = energy_certificate[1].text.strip().split('\r\n')
            
            try:
                rank_consumo = consumo[1]
                consumo_ranking_list.append(rank_consumo)
            except:
                rank_consumo = np.NaN
                consumo_ranking_list.append(rank_consumo)
                
            try:
                rank_emisiones = emisiones[0][-1]
                emissions_ranking_list.append(rank_emisiones)
            except:
                rank_emisiones = np.NaN
                emissions_ranking_list.append(rank_emisiones)
            
            
            #print(consumo)
            #print(emisiones)
            #print('rank_consumo', rank_consumo)
            #print('rank_emisiones', rank_emisiones)

            try:
                consupmtion_kilowatts = int(consumo[2][:-2])
                consupmtion_kilowatts_list.append(consupmtion_kilowatts)
                #print('consupmtion_kilowatts:', consupmtion_kilowatts)
            except:
                consupmtion_kilowatts = np.NaN
                consupmtion_kilowatts_list.append(consupmtion_kilowatts)
                #print('consupmtion_kilowatts:', consupmtion_kilowatts)

            if len(emisiones) == 1:
                emissions_kilograms = np.NaN
            else:
                emissions_kilograms = int(emisiones[1][:-15])                       

            emissions_kilograms_list.append(emissions_kilograms)
            #print('emissions_kilograms:', emissions_kilograms)

        else:
            #print('CERTIFICADO EN TRAMITE')
            rank_consumo = np.NaN
            rank_emisiones = np.NaN
            consupmtion_kilowatts = np.NaN
            emissions_kilograms = np.NaN

            consumo_ranking_list.append(rank_consumo)
            emissions_ranking_list.append(rank_emisiones)
            consupmtion_kilowatts_list.append(consupmtion_kilowatts)
            emissions_kilograms_list.append(emissions_kilograms)

            #print('rank_consumo:', rank_consumo)
            #print('rank_emisiones:', rank_emisiones)
            #print('consupmtion_kilowatts:', consupmtion_kilowatts)
            #print('emissions_kilograms:', emissions_kilograms)
          

    all_features_list.append(all_features)
    #print(all_features)
#print(consumo_ranking_list)
#print(emissions_ranking_list)
#print(consupmtion_kilowatts_list)
#print(emissions_kilograms_list)
# Out:
# 100%|██████████| 1515/1515 [16:15<00:00,  1.55it/s]

# %%
# THIS IS TO CHECK THAT ALL FEATURES WERE PROPERLY EXTRACTED AND DOUBLE CHECK IF THE LISTS HAVE THE SAME LENGHT TO PROPERLY BUILD THE DataFrame

print(len(all_features_list))
print(len(consumo_ranking_list))
print(len(emissions_ranking_list))
print(len(consupmtion_kilowatts_list))
print(len(emissions_kilograms_list))
# Out:
# 1515
# 1515
# 1515
# 1515
# 1515

# %%
print(all_features_list[0:10])
print()
print(consumo_ranking_list[0:10])
print()
print(emissions_ranking_list[0:10])
print()
print(consupmtion_kilowatts_list[0:10])
print()
print(emissions_kilograms_list[0:10])
# Out:
# [['Calefacción', 'Sin plaza parking', 'Aire acondicionado', 'Planta número 1', 'Año construcción 1952'], ['Calefacción', 'Amueblado', 'Aire acondicionado'], ['Calefacción', 'Sin plaza parking', 'Sin aire acondicionado', 'Planta número 1', 'Año construcción 1945'], ['Calefacción', 'Sin plaza parking', 'Aire acondicionado', 'Planta número 5', 'Año construcción 1960'], ['Calefacción', 'Sin plaza parking', 'Sin aire acondicionado', 'Año construcción 1964', 'Cerca de transporte público'], ['Calefacción', 'Sin plaza parking', 'Sin aire acondicionado', 'Planta número 5', 'Año construcción 1991'], ['Calefacción', 'Plaza parking', 'Aire acondicionado', 'Planta número 2', 'Año construcción 2000'], ['Calefacción', 'Sin plaza parking', 'Aire acondicionado', 'Planta número 1', 'Año construcción 1900'], [], ['Calefacción', 'Aire acondicionado', 'Cerca de transporte público']]
#
# ['F', 'G', 'C', 'D', 'E', 'E', 'C', 'E', nan, nan]
#
# ['E', 'G', 'C', 'C', 'E', 'E', 'C', 'E', nan, nan]
#
# [322, 99999, 84, 105, 271, 143, 71, 203, nan, nan]
#
# [66, 99999, 18, 21, 56, 37, 15, 39, nan, nan]

# %%
all_features_list[1]

# %%
full_description_list = []

for link in tqdm(unique_listings_urls):
    html = requests.get(link).content
    unique_soup = BeautifulSoup(html, 'html.parser')
    description_table = unique_soup.find_all('section', {'class': 'detail'})
    detailed_description = description_table[0].find_all('p', {'class': 'detail-description'})
    #print(detailed_description[0].text.replace('\xa0', ' ').replace('  ', ' '))
    full_description_list.append(detailed_description[0].text.replace('\xa0', ' ').replace('  ', ' '))
# Out:
# 100%|██████████| 1515/1515 [16:29<00:00,  1.53it/s]

# %%
all_listings_distribution_details_list = []
all_listings_general_features_list = []
all_listings_community_features_list = []

#DISTRIBUTION MOST RELEVANT AND REPEATED ITEMS
dist_rooms = []
dist_meters = []
dist_baths = []
dist_trastero = []
dist_lavadero = []
dist_terraza = []

# MOST RELEVANT AND REPEATED FEATURES. "CARACTERISTICAS PRINCIPALES"
feat_year_made = []
feat_unit_floor = []
feat_air_conditioner = []
feat_parking_spot = []
feat_heater = []

# COMMUNITY FEATURES: MOST RELEVANT OR REPEATED FEATURES. "EQUIPAMIENTO COMUNITARIO"
comm_elevator = []
comm_quota = []
comm_pool = []

for link in tqdm(unique_listings_urls):
    html = requests.get(link).content
    unique_soup = BeautifulSoup(html, 'html.parser')
    all_listing_details = unique_soup.find_all('article', {'class': 'has-aside'})
    
    distribution_details = all_listing_details[1].find_all('li')
    general_features_details = all_listing_details[2].find_all('li')
    community_equipment = all_listing_details[3].find_all('li')

    one_listing_distribution_details_list= []
    one_listing_all_features_details_list = []
    one_listing_all_community_equipment_list = []
 
    #TO EXTRACT DISTRIBUTION MOST RELEVANT AND REPEATED ITEMS TO LISTS.

    if str('habitac') in all_listing_details[1].text:
        dist_rooms.append(all_listing_details[1].text[int(all_listing_details[1].text.find('habit'))-4:int(all_listing_details[1].text.find('habit'))].strip())
    else:
        dist_rooms.append(np.NaN)

    if str('Superficie') in all_listing_details[1].text:
        dist_meters.append(all_listing_details[1].text[int(all_listing_details[1].text.find('Superficie')) + len('Superficie'):int(all_listing_details[1].text.find('m2'))].strip())
    else:
        dist_meters.append(np.NaN)

    if str('Baño') in all_listing_details[1].text:
        dist_baths.append(all_listing_details[1].text[int(all_listing_details[1].text.find('Baño')) - 3:int(all_listing_details[1].text.find('Baño'))].strip())
    else:
        dist_baths.append(np.NaN)

    if str('Trastero') in all_listing_details[1].text:
        dist_trastero.append(True)
    else:
        dist_trastero.append(np.NaN)

    if str('Lavadero') in all_listing_details[1].text:
        dist_lavadero.append(True)
    else:
        dist_lavadero.append(np.NaN)

    if str('Terraza') in all_listing_details[1].text:
        dist_terraza.append(all_listing_details[1].text[int(all_listing_details[1].text.find('Terraza'))+len('Terraza'):int(all_listing_details[1].text.find('Terraza'))+len('Terraza') + 4].strip())
    else:
        dist_terraza.append(np.NaN)

    #Distribution    
    for items in range(len(distribution_details)):
        #print(distribution_details[items].text)
        one_listing_distribution_details_list.append(distribution_details[items].text.strip().replace('\xa0', ' '))

    #General Features  
    for items in range(len(general_features_details)):
        if len(general_features_details[items]) <= 2:
            #print(general_features_details[items].text)
            one_listing_all_features_details_list.append(general_features_details[items].text.strip().replace('\xa0', ' '))
            
    #Community Equipment  
    for items in range(len(community_equipment)):
        if len(community_equipment[items]) <= 2:
            #print(community_equipment[items].text)
            one_listing_all_community_equipment_list.append(community_equipment[items].text.strip().replace('\xa0', ' '))


    #TO EXTRACT THE GENERAL FEATURES MOST RELEVANT AND REPEATED ITEMS TO LISTS.

    if str('Calefacción') in all_listing_details[2].text:
        feat_heater.append(True)
    elif str('Sin calefacción') in all_listing_details[2].text:
        feat_heater.append(False)
    else:
        feat_heater.append(np.NaN)

    if str('Aire acondicionado') in all_listing_details[2].text:
        feat_air_conditioner.append(True)
    elif str('Sin aire acondicionado') in all_listing_details[2].text:
        feat_air_conditioner.append(False)
    else:
        feat_air_conditioner.append(np.NaN)

    if str('Plaza parking') in all_listing_details[2].text:
        feat_parking_spot.append(True)
    elif str('Sin plaza parking') in all_listing_details[2].text:
        feat_parking_spot.append(False)
    else:
        feat_parking_spot.append(np.NaN)

    if str('Año construcción') in all_listing_details[2].text:
        feat_year_made.append(all_listing_details[2].text[int(all_listing_details[2].text.find('Año construcción')) + len('Año construcción'):int(all_listing_details[2].text.find('Año construcción')) + len('Año construcción') + 6].strip())
    else:
        feat_year_made.append(np.NaN)

    if str('Planta número') in all_listing_details[2].text:
        feat_unit_floor.append(all_listing_details[2].text[int(all_listing_details[2].text.find('Planta número')) + len('Planta número'):int(all_listing_details[2].text.find('Planta número')) + len('Planta número') + 3].strip())
    else:
        feat_unit_floor.append(np.NaN)
        
        
    #TO EXTRACT THE COMMUNITY MOST RELEVANT FEATURES AND REPEATED ITEMS TO LISTS.

    if str('Ascensor') in all_listing_details[3].text:
        comm_elevator.append(True)
    elif str('Sin ascensor') in all_listing_details[3].text:
        comm_elevator.append(False)
    else:
        comm_elevator.append(np.NaN)

    if str('Piscina comunitaria') in all_listing_details[3].text:
        comm_pool.append(True)
    else:
        comm_pool.append(np.NaN)

    if str('Cuota comunidad') in all_listing_details[3].text:
        comm_quota.append(all_listing_details[3].text[int(all_listing_details[3].text.find('Cuota comunidad')) + len('Cuota comunidad') :int(all_listing_details[3].text.find('€'))].strip())
    else:
        comm_quota.append(np.NaN)
    
    #THE FOLLOWING PART TO CREATE LISTS TO DOUBLE CHECK ITEMS.
    
    #Distribution
    #print(one_listing_distribution_details_list)
    all_listings_distribution_details_list.append(one_listing_distribution_details_list)

    #Features        
    #print(one_listing_all_features_details_list)
    all_listings_general_features_list.append(one_listing_all_features_details_list)
    
    #Community Features        
    #print(one_listing_all_community_equipment_list)
    all_listings_community_features_list.append(one_listing_all_community_equipment_list)
# Out:
# 100%|██████████| 1515/1515 [16:22<00:00,  1.54it/s]

# %%
print('\nCaracteristicas Distribución:\n')
print('dist_rooms', len(dist_rooms))
print('dist_meters', len(dist_meters))
print('dist_baths', len(dist_baths))
print('dist_trastero', len(dist_trastero))
print('dist_lavadero', len(dist_lavadero))
print('dist_terraza', len(dist_terraza))

print('\nCaracteristicas Generales:\n')
print('feat_year_made', len(feat_year_made))
print('feat_unit_floor', len(feat_unit_floor))
print('feat_air_conditioner', len(feat_air_conditioner))
print('feat_parking_spot', len(feat_parking_spot))
print('feat_heater', len(feat_heater))

print('\nEquipamiento Comunitario:\n')
print('comm_elevator', len(comm_elevator))
print('comm_pool', len(comm_pool))
print('comm_quota', len(comm_quota))


print('\nAll consolidated features_details lists:\n')
print('all_listings_distribution_details_list', len(all_listings_distribution_details_list))
print('all_listings_general_features_list', len(all_listings_general_features_list))
print('all_listings_community_features_list', len(all_listings_community_features_list))
# Out:
# Caracteristicas Distribución:
#
# dist_rooms 1515
# dist_meters 1515
# dist_baths 1515
# dist_trastero 1515
# dist_lavadero 1515
# dist_terraza 1515
#
# Caracteristicas Generales:
#
# feat_year_made 1515
# feat_unit_floor 1515
# feat_air_conditioner 1515
# feat_parking_spot 1515
# feat_heater 1515
#
# Equipamiento Comunitario:
#
# comm_elevator 1515
# comm_pool 1515
# comm_quota 1515
#
# All consolidated features_details lists:
#
# all_listings_distribution_details_list 1515
# all_listings_general_features_list 1515
# all_listings_community_features_list 1515

# %%
print('\nCaracteristicas Distribución:\n')
print('dist_rooms', dist_rooms[0:10])
print('dist_meters', dist_meters[0:10])
print('dist_baths', dist_baths[0:10])
print('dist_trastero', dist_trastero[0:10])
print('dist_lavadero', dist_lavadero[0:10])
print('dist_terraza', dist_terraza[0:10])

print('\nCaracteristicas Generales:\n')
print('feat_year_made', feat_year_made[0:10])
print('feat_unit_floor', feat_unit_floor[0:10])
print('feat_air_conditioner', feat_air_conditioner[0:10])
print('feat_parking_spot', feat_parking_spot[0:10])
print('feat_heater', feat_heater[0:10])

print('\nEquipamiento Comunitario:\n')
print('comm_elevator', comm_elevator[0:10])
print('comm_pool', comm_pool[0:10])
print('comm_quota', comm_quota[0:10])

print('\nAll consolidated features_details lists:\n')
print('all_listings_distribution_details_list', all_listings_distribution_details_list[0:10])
print('all_listings_general_features_list', all_listings_general_features_list[0:10])
print('all_listings_community_features_list', all_listings_community_features_list[0:10])
# Out:
# Caracteristicas Distribución:
#
# dist_rooms ['3', '4', '6', '2', '3', '1', '2', '3', '2', '1']
# dist_meters ['117', '113', '188', '71', '134', '49', '93', '105', '70', '84']
# dist_baths ['2', '3', '2', '2', '2', '1', '2', '1', '1', '1']
# dist_trastero [True, True, True, nan, nan, nan, True, True, nan, nan]
# dist_lavadero [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]
# dist_terraza [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]
#
# Caracteristicas Generales:
#
# feat_year_made ['1952', nan, '1945', '1960', '1964', '1991', '2000', '1900', nan, nan]
# feat_unit_floor ['1', nan, '1', '5', nan, '5', '2', '1', nan, nan]
# feat_air_conditioner [True, True, False, True, False, False, True, True, nan, True]
# feat_parking_spot [False, nan, False, False, False, False, True, False, nan, nan]
# feat_heater [True, True, True, True, True, True, True, True, nan, True]
#
# Equipamiento Comunitario:
#
# comm_elevator [True, True, True, True, False, True, True, False, nan, True]
# comm_pool [nan, nan, nan, nan, nan, nan, True, nan, nan, nan]
# comm_quota ['125', nan, '195', '37', '35', nan, nan, '130', nan, nan]
#
# All consolidated features_details lists:
#
# all_listings_distribution_details_list [['3 habitaciones', 'Superficie 117 m2', '2 Baños', 'Cocina tipo office: No', 'Estado cocina: buen estado', 'Trastero'], ['4 habitaciones', 'Superficie 113 m2', '3 Baños', 'Trastero'], ['6 habitaciones', 'Superficie 188 m2', '2 Baños', 'Cocina tipo office: No', 'Estado cocina: buen estado', 'Trastero'], ['2 habitaciones', 'Superficie 71 m2', '2 Baños', 'Cocina tipo office: No', 'Estado cocina: bueno'], ['3 habitaciones', 'Superficie 134 m2', '2 Baños', 'Cocina tipo office', 'Estado cocina: bueno'], ['1 habitación', 'Superficie 49 m2', '1 Baño', 'Cocina tipo office: No', 'Estado cocina: buen estado'], ['2 habitaciones', 'Superficie 93 m2', '2 Baños', 'Cocina tipo office: No', 'Estado cocina: buen estado', 'Trastero'], ['3 habitaciones', 'Superficie 105 m2', '1 Baño', 'Cocina tipo office: No', 'Estado cocina: buen estado', 'Trastero'], ['2 habitaciones', 'Superficie 70 m2', '1 Baño'], ['1 habitación', 'Superficie 84 m2', '1 Baño', 'Cocina tipo office']]
# all_listings_general_features_list [['Calefacción', 'Sin plaza parking', 'Aire acondicionado', 'Planta número 1', 'Año construcción 1952'], ['Calefacción', 'Amueblado', 'Aire acondicionado'], ['Calefacción', 'Sin plaza parking', 'Sin aire acondicionado', 'Planta número 1', 'Año construcción 1945'], ['Calefacción', 'Sin plaza parking', 'Aire acondicionado', 'Planta número 5', 'Año construcción 1960'], ['Calefacción', 'Sin plaza parking', 'Sin aire acondicionado', 'Año construcción 1964', 'Cerca de transporte público'], ['Calefacción', 'Sin plaza parking', 'Sin aire acondicionado', 'Planta número 5', 'Año construcción 1991'], ['Calefacción', 'Plaza parking', 'Aire acondicionado', 'Planta número 2', 'Año construcción 2000'], ['Calefacción', 'Sin plaza parking', 'Aire acondicionado', 'Planta número 1', 'Año construcción 1900'], [], ['Calefacción', 'Aire acondicionado', 'Cerca de transporte público']]
# all_listings_community_features_list [['Ascensor', 'Vigilancia', 'Cuota comunidad 125€'], ['Ascensor'], ['Ascensor', 'Jardín comunitario', 'Vigilancia', 'Cuota comunidad 195€'], ['Ascensor', 'Cuota comunidad 37€'], ['Sin ascensor', 'Cuota comunidad 35€'], ['Ascensor', 'Jardín comunitario', 'Vigilancia'], ['Ascensor', 'Piscina comunitaria', 'Jardín comunitario', 'Vigilancia'], ['Sin ascensor', 'Cuota comunidad 130€'], [], ['Ascensor']]

# %%
all_listings_numbers = []
all_listing_time_tags = []
all_listings_gif_url = []
all_listings_area_url = []


for link in tqdm(unique_listings_urls):
    html = requests.get(link).content
    unique_soup = BeautifulSoup(html, 'html.parser')

#This is to retrieve the listing id / unique number.

    listing_id_section = unique_soup.find_all('section', {'class': 'options bg-white'})
    listing_unique_id = listing_id_section[0].find_all('span', {'class': 'detail-id'})
    listing_unique_id[0].text

    listing_number = listing_unique_id[0].text[9:]
    all_listings_numbers.append(listing_number)


#This is to retrieve the listing last modification or listing time-tag.

    time_tag_item = unique_soup.find_all('p', {'class': 'time-tag'})
    time_tag = time_tag_item[0].time.text
    all_listing_time_tags.append(time_tag)
    
#This is to retreive a URL for a Map gif image and also a URL of the area where the listing is located. (With similar listings)    
    map_section = unique_soup.find_all('section', {'class': 'map'})
    map_image = map_section[0].find_all('div', {'class': 'map-image'})
    map_zone_url = unique_soup.find_all('div', {'class': 'map-more'})
    #print('https:' + map_image[1].img.get('src')) # Esta es una foto de la zona
    
    try:
        all_listings_gif_url.append('https:' + map_image[1].img.get('src'))
    except:
        all_listings_gif_url.append(np.NaN)
        
    try:    
        all_listings_area_url.append(map_zone_url[0].a.get('href'))
    except:
        all_listings_area_url.append(np.NaN)
# Out:
# 100%|██████████| 1515/1515 [16:38<00:00,  1.52it/s]

# %%
print('all_listings_numbers:', len(all_listings_numbers))
print('all_listing_time_tags:', len(all_listing_time_tags))
print('all_listings_gif_url:', len(all_listings_gif_url))
print('all_listings_area_url:', len(all_listings_area_url))
print()
print(all_listings_numbers[0:10])
print()
print(all_listing_time_tags[0:10])
print()
print(all_listings_gif_url[0:10])
print()
print(all_listings_area_url[0:10])
# Out:
# all_listings_numbers: 1515
# all_listing_time_tags: 1515
# all_listings_gif_url: 1515
# all_listings_area_url: 1515
#
# ['15511003002180', '23878000004181', '15511003002590', '15511003002757', '15511003002896', '15511003002586', '15511003002656', '15511003002573', '16424000000673', '548003171458']
#
# ['03/05/2021', '03/05/2021', '03/05/2021', '03/05/2021', '03/05/2021', '03/05/2021', '03/05/2021', '03/05/2021', '22/04/2021', '23/03/2021']
#
# ['https://static11.habimg.com/imgh/15511-3002180/imgv2-gmaps-3002180_0420.gif', 'https://static11.habimg.com/imgh/23878-4181/imgv2-gmaps-4181_5741.gif', 'https://static11.habimg.com/imgh/15511-3002590/imgv2-gmaps-3002590_2817.gif', 'https://static11.habimg.com/imgh/15511-3002757/imgv2-gmaps-3002757_1911.gif', 'https://static11.habimg.com/imgh/15511-3002896/imgv2-gmaps-3002896_2243.gif', 'https://static11.habimg.com/imgh/15511-3002586/imgv2-gmaps-3002586_9519.gif', 'https://static11.habimg.com/imgh/15511-3002656/imgv2-gmaps-3002656_4648.gif', 'https://static11.habimg.com/imgh/15511-3002573/imgv2-gmaps-3002573_7829.gif', 'https://static11.habimg.com/imgh/16424-673/imgv2-gmaps-673_3542.gif', 'https://static11.habimg.com/imgh/548-3164813/imgv2-gmaps-3164813_9352.gif']
#
# ['https://www.habitaclia.com/comprar-piso-en-madrid-zona_arapiles/provincia_madrid-madrid_capital-area_1/vivienda/vistamapa.htm', 'https://www.habitaclia.com/comprar-piso-en-madrid-zona_valdezarza/provincia_madrid-madrid_capital-area_1/vivienda/vistamapa.htm', 'https://www.habitaclia.com/comprar-piso-en-madrid-zona_gaztambide/provincia_madrid-madrid_capital-area_1/vivienda/vistamapa.htm', 'https://www.habitaclia.com/comprar-piso-en-madrid-zona_gaztambide/provincia_madrid-madrid_capital-area_1/vivienda/vistamapa.htm', 'https://www.habitaclia.com/comprar-triplex-en-madrid-zona_pinar_del_rey/provincia_madrid-madrid_capital-area_1/vivienda/vistamapa.htm', 'https://www.habitaclia.com/comprar-piso-en-madrid-zona_palos_de_moguer/provincia_madrid-madrid_capital-area_1/vivienda/vistamapa.htm', 'https://www.habitaclia.com/comprar-piso-en-madrid-zona_las_tablas/provincia_madrid-madrid_capital-area_1/vivienda/vistamapa.htm', 'https://www.habitaclia.com/comprar-piso-en-madrid-zona_universidad_malasana/provincia_madrid-madrid_capital-area_1/vivienda/vistamapa.htm', 'https://www.habitaclia.com/comprar-piso-en-madrid-zona_embajadores_lavapies/provincia_madrid-madrid_capital-area_1/vivienda/vistamapa.htm', 'https://www.habitaclia.com/comprar-piso-en-madrid-zona_sol/provincia_madrid-madrid_capital-area_1/vivienda/vistamapa.htm']

# %%
#Summary Price Metrics

listing_price_from_metrics = []
distric_price_from_metrics = []
square_meter_price_from_metric = []

for link in tqdm(unique_listings_urls):
    html = requests.get(link).content
    unique_soup = BeautifulSoup(html, 'html.parser')
    price_metrics = unique_soup.find_all('div', {'class': 'round-block'})
    price_metrics_details = price_metrics[0].find_all('div', {'class': 'bg-white round-100 f-left'})

#This is to retrieve the district average price of the listing.
#Listing price and listing price per square meter is also available using this same tag/class.

    try:
        listing_price_from_metrics.append(price_metrics_details[0].text[:int(price_metrics_details[0].text.find('€ Precio del anuncio'))].strip())
    except:
        listing_price_from_metrics.append(np.NaN)

    try:
        distric_price_from_metrics.append(price_metrics_details[1].text[:int(price_metrics_details[1].text.find('€/m2€/m2 distrito'))].strip())
    except:
        distric_price_from_metrics.append(np.NaN)

    try:
        square_meter_price_from_metric.append(price_metrics_details[2].text[:int(price_metrics_details[2].text.find('€/m2€/m2 del anuncio'))].strip())
    except:
        square_meter_price_from_metric.append(np.NaN)


# print()
# print('listing_price_from_metrics:', listing_price_from_metrics)
# print()
# print('distric_price_from_metrics:', distric_price_from_metrics)
# print()
# print('square_meter_price_from_metric:', square_meter_price_from_metric)
# Out:
# 100%|██████████| 1515/1515 [17:14<00:00,  1.46it/s]
# listing_price_from_metrics: ['479.000', '710.000', '640.000', '380.000', '299.900', '190.000', '360.000', '349.900', '290.000', '470.000', '2.990.000', '306.000', '750.000', '139.000', '140.000', '875.000', '569.000', '239.000', '255.000', '530.000', '830.000', '1.200.000', '639.000', '540.000', '745.000', '630.000', '840.000', '545.000', '876.000', '420.000', '435.000', '820.000', '850.000', '170.000', '680.000', '560.000', '1.590.000', '620.000', '820.000', '399.000', '1.180.000', '1.335.000', '499.000', '1.030.000', '230.000', '1.950.000', '445.000',
print()
print('listing_price_from_metrics:', listing_price_from_metrics[0:10])
print()
print('distric_price_from_metrics:', distric_price_from_metrics[0:10])
print()
print('square_meter_price_from_metric:', square_meter_price_from_metric[0:10])
# Out:
# listing_price_from_metrics: 1515
# distric_price_from_metrics: 1515
# square_meter_price_from_metric: 1515
#
# listing_price_from_metrics: ['479.000', '710.000', '640.000', '380.000', '299.900', '190.000', '360.000', '349.900', '290.000', '470.000']
#
# distric_price_from_metrics: ['5.656', '4.001', '5.656', '5.656', '2.901', '4.025', '3.813', '5.284', '5.284', '5.284']
#
# square_meter_price_from_metric: ['4.094', '6.283', '3.404', '5.352', '2.238', '3.878', '3.871', '3.332', '4.143', '5.595']

# %%
habit_sample_dict = {'URL': unique_listings_urls,
                     'listing_number': all_listings_numbers,
                     'time_tag': all_listing_time_tags,
                     'location_list': location_list,
                     'price_list': price_list,
                     'squared_meters_list': squared_meters_list,
                     'number_of_rooms_list': number_of_rooms_list,
                     'number_of_bathrooms_list': number_of_bathrooms_list,
                     'euros_per_meter_list': euros_per_meter_list,
                     'dist_rooms': dist_rooms,
                     'dist_meters': dist_meters,
                     'dist_baths': dist_baths,
                     'dist_trastero': dist_trastero,
                     'dist_lavadero': dist_lavadero,
                     'dist_terraza': dist_terraza,
                     'feat_year_made': feat_year_made,
                     'feat_unit_floor': feat_unit_floor,
                     'feat_air_conditioner': feat_air_conditioner,
                     'feat_parking_spot': feat_parking_spot,
                     'feat_heater': feat_heater,
                     'comm_elevator': comm_elevator,
                     'comm_quota': comm_quota,
                     'comm_pool': comm_pool,
                     'consumo_ranking_list': consumo_ranking_list,
                     'emissions_ranking_list': emissions_ranking_list,
                     'consupmtion_kilowatts_list': consupmtion_kilowatts_list,
                     'emissions_kilograms_list': emissions_kilograms_list,
                     'listing_price_from_metrics': listing_price_from_metrics,
                     'distric_price_from_metrics': distric_price_from_metrics,
                     'square_meter_price_from_metric': square_meter_price_from_metric,
                     'all_listings_gif_url': all_listings_gif_url,
                     'all_listings_area_url': all_listings_area_url,
                     'full_description_list': full_description_list,
                     'all_features_list': all_features_list,
                     'all_listings_distribution_details_list': all_listings_distribution_details_list,
                     'all_listings_general_features_list': all_listings_general_features_list,
                     'all_listings_community_features_list': all_listings_community_features_list
                    }

# List to columns:
# 1 - unique_listings_urls = []
# 2 - all_listings_numbers = []
# 3 - all_listing_time_tags = []
# 4 - location_list = []
# 5 - price_list = []
# 6 - squared_meters_list = []
# 7 - number_of_rooms_list = []
# 8 - number_of_bathrooms_list = []
# 9 - euros_per_meter_list = []

#DISTRIBUTION MOST RELEVANT AND REPEATED ITEMS
# 10 - dist_rooms = []
# 11 -  dist_meters = []
# 12 - dist_baths = []
# 13 - dist_trastero = []
# 14 - dist_lavadero = []
# 15 - dist_terraza = []

# MOST RELEVANT AND REPEATED FEATURES. "CARACTERISTICAS PRINCIPALES"
# 16 - feat_year_made = []
# 17 - feat_unit_floor = []
# 18 - feat_air_conditioner = []
# 19 - feat_parking_spot = []
# 20 - feat_heater = []

# COMMUNITY FEATURES: MOST RELEVANT OR REPEATED FEATURES. "EQUIPAMIENTO COMUNITARIO"
# 21 - comm_elevator = []
# 22 - comm_quota = []
# 23 - comm_pool = []

# 24 - consumo_ranking_list = []
# 25 - emissions_ranking_list = []
# 26 - consupmtion_kilowatts_list = []
# 27 - emissions_kilograms_list = []

# 28 - listing_price_from_metrics = []
# 29 - distric_price_from_metrics = []
# 30 - square_meter_price_from_metric = []

# 31 - all_listings_gif_url = []
# 32 - all_listings_area_url = []

# 33 - full_description_list = []

# 34 - all_features_list = []

# 35 - all_listings_distribution_details_list = []
# 36 - all_listings_general_features_list = []
# 37 - all_listings_community_features_list = []

# %%
import pandas as pd

habit_sample_df = pd.DataFrame(habit_sample_dict)

# %%
habit_sample_df.head(10)
# Out:
#                                                  URL  listing_number  \
# 0  https://www.habitaclia.com/comprar-piso-fenome...  15511003002180
# 1  https://www.habitaclia.com/comprar-piso-c_doct...  23878000004181
# 2  https://www.habitaclia.com/comprar-piso-con_te...  15511003002590
# 3  https://www.habitaclia.com/comprar-piso-estupe...  15511003002757
# 4  https://www.habitaclia.com/comprar-triplex-aco...  15511003002896
# 5  https://www.habitaclia.com/comprar-piso-genial...  15511003002586
# 6  https://www.habitaclia.com/comprar-piso-estupe...  15511003002656
# 7  https://www.habitaclia.com/comprar-piso-esplen...  15511003002573
# 8  https://www.habitaclia.com/comprar-piso-impeca...  16424000000673
# 9  https://www.habitaclia.com/comprar-piso-obra_n...    548003171458
#
#      time_tag         location_list price_list squared_meters_list  \
# 0  03/05/2021              Arapiles    479.000                 117
# 1  03/05/2021            Valdezarza    710.000                 113
# 2  03/05/2021            Gaztambide    640.000                 188
# 3  03/05/2021            Gaztambide    380.000                  71
# 4  03/05/2021         Pinar del Rey    299.900                 134
# 5  03/05/2021       Palos de Moguer    190.000                  49
# 6  03/05/2021            Las Tablas    360.000                  93
# 7  03/05/2021  Universidad-Malasaña    349.900                 105
# 8  22/04/2021  Embajadores-Lavapiés    290.000                  70
# 9  23/03/2021                   Sol    470.000          desde \n84
#
#   number_of_rooms_list number_of_bathrooms_list euros_per_meter_list  \
# 0                    3                        2                4.094
# 1                    4                        3                6.283
# 2                    6                        2                3.404
# 3                    2                        2                5.352
# 4                    3                        2                2.238
# 5                    1                        1                3.878
# 6                    2                        2                3.871
# 7                    3                        1                3.332
# 8                    2                        1                4.143
# 9                    1                        1                5.595
#
#   dist_rooms  ... listing_price_from_metrics distric_price_from_metrics  \
# 0          3  ...                    479.000                      5.656
# 1          4  ...                    710.000                      4.001
# 2          6  ...                    640.000                      5.656
# 3          2  ...                    380.000                      5.656
# 4          3  ...                    299.900                      2.901
# 5          1  ...                    190.000                      4.025
# 6          2  ...                    360.000                      3.813
# 7          3  ...                    349.900                      5.284
# 8          2  ...                    290.000                      5.284
# 9          1  ...                    470.000                      5.284
#
#   square_meter_price_from_metric  \
# 0                          4.094
# 1                          6.283
# 2                          3.404
# 3                          5.352
# 4                          2.238
# 5                          3.878
# 6                          3.871
# 7                          3.332
# 8                          4.143
# 0  [Calefacción, Sin plaza parking, Aire acondici...
# 1       [Calefacción, Amueblado, Aire acondicionado]
# 2  [Calefacción, Sin plaza parking, Sin aire acon...
# 3  [Calefacción, Sin plaza parking, Aire acondici...
# 4  [Calefacción, Sin plaza parking, Sin aire acon...
# 5  [Calefacción, Sin plaza parking, Sin aire acon...
# 6  [Calefacción, Plaza parking, Aire acondicionad...
# 7  [Calefacción, Sin plaza parking, Aire acondici...
# 8                                                 []
# 9  [Calefacción, Aire acondicionado, Cerca de tra...
#
#                 all_listings_community_features_list
# 0       [Ascensor, Vigilancia, Cuota comunidad 125€]
# 1                                         [Ascensor]
# 2  [Ascensor, Jardín comunitario, Vigilancia, Cuo...
# 3                    [Ascensor, Cuota comunidad 37€]
# 4                [Sin ascensor, Cuota comunidad 35€]
# 5         [Ascensor, Jardín comunitario, Vigilancia]
# 6  [Ascensor, Piscina comunitaria, Jardín comunit...
# 7               [Sin ascensor, Cuota comunidad 130€]
# 8                                                 []
# 9                                         [Ascensor]
#
# [10 rows x 37 columns]

# %%
habit_sample_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1515 entries, 0 to 1514
# Data columns (total 37 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   URL                                     1515 non-null   object
#  1   listing_number                          1515 non-null   object
#  2   time_tag                                1515 non-null   object
#  3   location_list                           1515 non-null   object
#  4   price_list                              1515 non-null   object
#  5   squared_meters_list                     1515 non-null   object
#  6   number_of_rooms_list                    1500 non-null   object
#  7   number_of_bathrooms_list                1509 non-null   object
#  8   euros_per_meter_list                    1515 non-null   object
#  9   dist_rooms                              1500 non-null   object
#  10  dist_meters                             1515 non-null   object
#  11  dist_baths                              1507 non-null   object
#  12  dist_trastero                           422 non-null    object
#  13  dist_lavadero                           171 non-null    object
#  14  dist_terraza                            76 non-null     object
#  15  feat_year_made                          984 non-null    object
#  16  feat_unit_floor                         216 non-null    object
#  17  feat_air_conditioner                    1143 non-null   object
#  18  feat_parking_spot                       577 non-null    object
#  19  feat_heater                             1238 non-null   object
#  20  comm_elevator                           974 non-null    object
#  21  comm_quota                              231 non-null    object
#  22  comm_pool                               201 non-null    object
#  23  consumo_ranking_list                    410 non-null    object
#  24  emissions_ranking_list                  410 non-null    object
#  25  consupmtion_kilowatts_list              328 non-null    float64
#  26  emissions_kilograms_list                317 non-null    float64
#  27  listing_price_from_metrics              1515 non-null   object
#  28  distric_price_from_metrics              1515 non-null   object
#  29  square_meter_price_from_metric          1515 non-null   object
#  30  all_listings_gif_url                    1503 non-null   object
#  31  all_listings_area_url                   1503 non-null   object
#  32  full_description_list                   1515 non-null   object
#  33  all_features_list                       1515 non-null   object
#  34  all_listings_distribution_details_list  1515 non-null   object
#  35  all_listings_general_features_list      1515 non-null   object
#  36  all_listings_community_features_list    1515 non-null   object
# dtypes: float64(2), object(35)
# memory usage: 438.1+ KB

# %%
# I noticed that in a few iterations I retrieved an unwanted string. THis is to find/count them.


habit_sample_df[habit_sample_df['squared_meters_list'].str.contains('desde \n')]
# Out:
#                                                     URL  listing_number  \
# 9     https://www.habitaclia.com/comprar-piso-obra_n...    548003171458
# 275   [Ascensor, Piscina comunitaria, Jardín comunit...
# 300   [Ascensor, Jardín comunitario, Equipamiento de...
# 309   [Ascensor, Piscina comunitaria, Jardín comunit...
# 310   [Ascensor, Piscina comunitaria, Jardín comunit...
# 316           [Piscina comunitaria, Jardín comunitario]
# 322   [Ascensor, Piscina comunitaria, Jardín comunit...
# 341   [Ascensor, Piscina comunitaria, Jardín comunit...
# 414   [Ascensor, Piscina comunitaria, Jardín comunit...
# 421   [Ascensor, Piscina comunitaria, Jardín comunit...
# 425                                          [Ascensor]
# 438                               [Piscina comunitaria]
# 450                      [Ascensor, Jardín comunitario]
# 465   [Ascensor, Jardín comunitario, Equipamiento de...
# 1014  [Ascensor, Jardín comunitario, Equipamiento de...
# 1174  [Ascensor, Piscina comunitaria, Jardín comunit...
# 1185  [Ascensor, Piscina comunitaria, Jardín comunit...
#
# [22 rows x 37 columns]

# %%
# This is to remove the unwanted part of the string.

habit_sample_df['squared_meters_list'] = habit_sample_df['squared_meters_list'].astype(str).str.replace('desde \n','')

# %%
habit_sample_df[habit_sample_df['squared_meters_list'].str.contains('desde \n')]
# Out:
# Empty DataFrame
# Columns: [URL, listing_number, time_tag, location_list, price_list, squared_meters_list, number_of_rooms_list, number_of_bathrooms_list, euros_per_meter_list, dist_rooms, dist_meters, dist_baths, dist_trastero, dist_lavadero, dist_terraza, feat_year_made, feat_unit_floor, feat_air_conditioner, feat_parking_spot, feat_heater, comm_elevator, comm_quota, comm_pool, consumo_ranking_list, emissions_ranking_list, consupmtion_kilowatts_list, emissions_kilograms_list, listing_price_from_metrics, distric_price_from_metrics, square_meter_price_from_metric, all_listings_gif_url, all_listings_area_url, full_description_list, all_features_list, all_listings_distribution_details_list, all_listings_general_features_list, all_listings_community_features_list]
# Index: []
#
# [0 rows x 37 columns]

# %%
habit_sample_df.dtypes
# Out:
# URL                                        object
# listing_number                             object
# time_tag                                   object
# location_list                              object
# price_list                                 object
# squared_meters_list                        object
# number_of_rooms_list                       object
# number_of_bathrooms_list                   object
# euros_per_meter_list                       object
# dist_rooms                                 object
# dist_meters                                object
# dist_baths                                 object
# dist_trastero                              object
# dist_lavadero                              object
# dist_terraza                               object
# feat_year_made                             object
# feat_unit_floor                            object
# feat_air_conditioner                       object
# feat_parking_spot                          object
# feat_heater                                object
# comm_elevator                              object
# comm_quota                                 object
# comm_pool                                  object
# consumo_ranking_list                       object
# emissions_ranking_list                     object
# consupmtion_kilowatts_list                float64
# emissions_kilograms_list                  float64
# listing_price_from_metrics                 object
# distric_price_from_metrics                 object
# square_meter_price_from_metric             object
# all_listings_gif_url                       object
# all_listings_area_url                      object
# full_description_list                      object
# all_features_list                          object
# all_listings_distribution_details_list     object
# all_listings_general_features_list         object
# all_listings_community_features_list       object
# dtype: object

# %%
#This one I changed because excel transforms the number to scientific notation because of its lenght. I want to leave it as is in the cvs file.

habit_sample_df['listing_number'] = habit_sample_df['listing_number'].astype(str)
habit_sample_df['listing_number']
# Out:
# 0       15511003002180
# 1       23878000004181
# 2       15511003002590
# 3       15511003002757
# 4       15511003002896
#              ...
# 1510    15511003003267
# 1511    15511003003269
# 1512    15511003003287
# 1513    15511003003339
# 1514    15511003003341
# Name: listing_number, Length: 1515, dtype: object

# %%
#Because my Excel is set with comma for thousands and I want to check the CSV file in Excel, I needed to change to string to preserve the whole numbers.
#Othersise, sometimes prices shown as 350.000 ended up as 350 in the cvs file.

#Columns to apply to:
#price_list 
#euros_per_meter_list
#listing_price_from_metrics
#distric_price_from_metrics
#square_meter_price_from_metric

# %%
habit_sample_df.price_list
# Out:
# 0       479.000
# 1       710.000
# 2       640.000
# 3       380.000
# 4       299.900
#          ...
# 1510    390.000
# 1511    550.000
# 1512    665.000
# 1513    664.900
# 1514    540.000
# Name: price_list, Length: 1515, dtype: object

# %%
habit_sample_df['price_list'] = habit_sample_df['price_list'].astype(str).str.replace('.',',')
habit_sample_df['euros_per_meter_list'] = habit_sample_df['euros_per_meter_list'].astype(str).str.replace('.',',')
habit_sample_df['listing_price_from_metrics'] = habit_sample_df['listing_price_from_metrics'].astype(str).str.replace('.',',')
habit_sample_df['distric_price_from_metrics'] = habit_sample_df['distric_price_from_metrics'].astype(str).str.replace('.',',')
habit_sample_df['square_meter_price_from_metric'] = habit_sample_df['square_meter_price_from_metric'].astype(str).str.replace('.',',')
# Out:
# <ipython-input-187-1576475a5bc7>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   habit_sample_df['price_list'] = habit_sample_df['price_list'].astype(str).str.replace('.',',')
# <ipython-input-187-1576475a5bc7>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   habit_sample_df['euros_per_meter_list'] = habit_sample_df['euros_per_meter_list'].astype(str).str.replace('.',',')
# <ipython-input-187-1576475a5bc7>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   habit_sample_df['listing_price_from_metrics'] = habit_sample_df['listing_price_from_metrics'].astype(str).str.replace('.',',')
# <ipython-input-187-1576475a5bc7>:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   habit_sample_df['distric_price_from_metrics'] = habit_sample_df['distric_price_from_metrics'].astype(str).str.replace('.',',')
# <ipython-input-187-1576475a5bc7>:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   habit_sample_df['square_meter_price_from_metric'] = habit_sample_df['square_meter_price_from_metric'].astype(str).str.replace('.',',')

# %%
habit_sample_df
# Out:
#                                                     URL  listing_number  \
# 0     https://www.habitaclia.com/comprar-piso-fenome...  15511003002180
# 1     https://www.habitaclia.com/comprar-piso-c_doct...  23878000004181
# 2     https://www.habitaclia.com/comprar-piso-con_te...  15511003002590
# 3     https://www.habitaclia.com/comprar-piso-estupe...  15511003002757
# 4     https://www.habitaclia.com/comprar-triplex-aco...  15511003002896
# ...                                                 ...             ...
# 1510  https://www.habitaclia.com/comprar-piso-fantas...  15511003003267
# 1511  https://www.habitaclia.com/comprar-piso-admira...  15511003003269
# 1512  https://www.habitaclia.com/comprar-piso-acoged...  15511003003287
# 1513  https://www.habitaclia.com/comprar-piso-perfec...  15511003003339
# 1514  https://www.habitaclia.com/comprar-piso-fabulo...  15511003003341
#
#         time_tag                  location_list price_list  \
# 0     03/05/2021                       Arapiles    479,000
# 1     03/05/2021                     Valdezarza    710,000
# 2     03/05/2021                     Gaztambide    640,000
# 3     03/05/2021                     Gaztambide    380,000
# 4     Estupendo piso en Hortaleza     Compraventa en...
# ...                                                 ...
# 1510  Espléndido piso en MoratalazHousfy, compravent...
# 1511  Acogedor piso en ChamartínHousfy sin intermedi...
# 1512  Fenomenal piso en ChamberíCompraventa entre pa...
# 1513  Encantador piso en HortalezaHousfy sin interme...
# 1514  Fenomenal piso en HortalezaCompra tu piso con ...
#
#                                       all_features_list  \
# 0     [Calefacción, Sin plaza parking, Aire acondici...
# 1          [Calefacción, Amueblado, Aire acondicionado]
# 2     [Calefacción, Sin plaza parking, Sin aire acon...
# 3     [Calefacción, Sin plaza parking, Aire acondici...
# 4     [Calefacción, Sin plaza parking, Sin aire acon...
# ...                                                 ...
# 1510  [Calefacción, Plaza parking, Amueblado, Sin ai...
# 1511  [Calefacción, Plaza parking, Aire acondicionad...
# 1512  [Sin calefacción, Sin plaza parking, Sin aire ...
# 1513  [Calefacción, Plaza parking, Amueblado, Aire a...
# 1514  [Calefacción, Plaza parking, Aire acondicionad...
#
#                  all_listings_distribution_details_list  \
# 0     [3 habitaciones, Superficie 117 m2, 2 Baños, C...
# 1     [4 habitaciones, Superficie 113 m2, 3 Baños, T...
# 2     [6 habitaciones, Superficie 188 m2, 2 Baños, C...
# 3     [2 habitaciones, Superficie 71 m2, 2 Baños, Co...
# 4     [3 habitaciones, Superficie 134 m2, 2 Baños, C...
# ...                                                 ...
# 1510  [3 habitaciones, Superficie 110 m2, 2 Baños, C...
# 1511  [3 habitaciones, Superficie 100 m2, 2 Baños, C...
# 1512  [4 habitaciones, Superficie 136 m2, 3 Aseos, C...
# 1513  [3 habitaciones, Superficie 108 m2, Terraza 38...
# 1514  [3 habitaciones, Superficie 102 m2, 2 Baños, C...
#
#                      all_listings_general_features_list  \
# 0     [Calefacción, Sin plaza parking, Aire acondici...
# 1          [Calefacción, Amueblado, Aire acondicionado]
# 2     [Calefacción, Sin plaza parking, Sin aire acon...
# 3     [Calefacción, Sin plaza parking, Aire acondici...
# 4     [Calefacción, Sin plaza parking, Sin aire acon...
# ...                                                 ...
# 1510  [Calefacción, Plaza parking, Amueblado, Sin ai...
# 1511  [Calefacción, Plaza parking, Aire acondicionad...
# 1512  [Sin calefacción, Sin plaza parking, Sin aire ...
# 1513  [Calefacción, Plaza parking, Amueblado, Aire a...
# 1514  [Calefacción, Plaza parking, Aire acondicionad...
#
#                    all_listings_community_features_list
# 0          [Ascensor, Vigilancia, Cuota comunidad 125€]
# 1                                            [Ascensor]
# 2     [Ascensor, Jardín comunitario, Vigilancia, Cuo...
# 3                       [Ascensor, Cuota comunidad 37€]
# 4                   [Sin ascensor, Cuota comunidad 35€]
# ...                                                 ...
# 1510  [Ascensor, Jardín comunitario, Vigilancia, Cuo...
# 1511       [Ascensor, Vigilancia, Cuota comunidad 195€]
# 1512                                         [Ascensor]
# 1513  [Ascensor, Piscina comunitaria, Jardín comunit...
# 1514  [Ascensor, Piscina comunitaria, Jardín comunit...
#
# [1515 rows x 37 columns]

# %%
habit_sample_df.to_csv('/Users/manuelaquino/Bootcamp/final_project/data/habit_sample.csv')
